# %% [markdown]
# SCRAPING NEWS USING PYTHON BEAUTIFUL SOUP

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from urllib.parse import urljoin, urlparse

# %% [markdown]
# SCRIPT

# %%
# Define the URLs and blocks to scrape
urls = [
    {"url": "https://www.bramptonguardian.com/news/", "block": "2886699"},
    {"url": "https://www.mississauga.com/news/", "block": "2901984"},
    {"url": "https://www.durhamregion.com/news/", "block": "2891595"},
    {"url": "https://www.insidehalton.com/news/", "block": "2901111"},
    {"url": "https://www.yorkregion.com/news/", "block": "2858511"},
    {"url": "https://www.toronto.com/news/", "block": "1202226"}
]

def ensure_valid_url(url):
    """Ensure the URL has a scheme and is fully qualified."""
    parsed_url = urlparse(url)
    if not parsed_url.scheme:
        url = "https://" + url
    return url

def scrape_page(datau):
    url = ensure_valid_url(datau["url"])
    block_id = datau["block"]
    data = []

    # Send request to the URL
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve {url}")
        return []

    # Parse the page content
    soup = BeautifulSoup(response.content, "html.parser")
    articles = soup.select(f"section #block-{block_id} article")

    # Extract data from each article
    for article in articles:
        headline_element = article.select_one(".card-headline h4 a")
        if not headline_element:
            continue

        body = headline_element.get_text()
        # Ensure the article URL is fully qualified
        article_url = urljoin(url, headline_element["href"])
        img_element = article.select_one(".image .tnt-blurred-image img")
        img_url = img_element["src"] if img_element else "alt"

        # Get article description from the article page
        description = scrape_article_description(article_url)

        data.append({
            "body": body,
            "img": img_url,
            "url": article_url,
            "description": description
        })

    return data

def scrape_article_description(article_url):
    article_url = ensure_valid_url(article_url)

    # Send request to the article URL
    response = requests.get(article_url)
    if response.status_code != 200:
        print(f"Failed to retrieve {article_url}")
        return ""

    # Parse the article content
    soup = BeautifulSoup(response.content, "html.parser")
    des_elements = soup.select(".asset-body p")
    description = " ".join([p.get_text() for p in des_elements])
    return description

# Scrape data from all URLs
all_data = []
for datau in urls:
    print(f"Scraping {datau['url']}...")
    page_data = scrape_page(datau)
    all_data.extend(page_data)

# Save the data to a JSON file
with open("news_data.json", "w", encoding="utf-8") as f:
    json.dump(all_data, f, ensure_ascii=False, indent=2)

print("News data saved!")


df=pd.DataFrame(all_data)
print(df)
# Out:
# Scraping https://www.bramptonguardian.com/news/...
# Scraping https://www.mississauga.com/news/...
# Scraping https://www.durhamregion.com/news/...
# Scraping https://www.insidehalton.com/news/...
# Scraping https://www.yorkregion.com/news/...
# Scraping https://www.toronto.com/news/...
# News data saved!
#                                                  body  \
# 0   \n        \n\n        Man rushed to hospital a...
# 1   \n        \n\n        Ready for some winter fu...
# 2   \n        \n\n        ‘Honour the incredible s...
# 3   \n        \n\n        Got mail? Here are other...
# 4   \n        \n\n        Ontario, Canada recalls:...
# 5   \n        \n\n        ‘LANES CLOSED’: Major la...
# 6   \n        \n\n        Still want to see Taylor...
# 7   \n        \n\n        New Canada Post stamps p...
# 8   \n        \n\n        ‘We’re liable’: Mississa...
# 9   \n        \n\n        ‘LANES CLOSED’: Major la...
# 10  \n        \n\n        Man with ties to Peel Re...
# 11  \n        \n\n        Mississauga Mayor Caroly...
# 12  \n        \n\n        MiWay buses not entering...
# 13  \n        \n\n        Suspicious package promp...
# 1   The holiday magic of WinterFest returns to Can...
# 2   The City of Brampton is hosting Remembrance Da...
# 3   As the threat of a possible work stoppage at C...
# 4   Thousands of space heaters sold on Amazon, bat...
# 5   Drivers in Peel Region should expect delays or...
# 6   You still have a chance to win some Taylor Swi...
# 7   Ahead of Remembrance Day, Canada Post has issu...
# 8   It’s game over for a bid to allow sports on Mi...
# 9   Drivers in Peel Region should expect delays or...
# 10  A man with ties to Peel Region has been accuse...
# 11  Mississauga may once again consider banning fi...
# 12  MiWay buses aren’t entering Brampton Gateway T...
# 13  A suspicious package that prompted the evacuat...
# 14  Mississauga may move to ban protests near plac...
# 15  A Mississauga man is one of two people charged...
# 16  The holiday magic of WinterFest returns to Can...
# 17  As the threat of a possible work stoppage at C...
# 18  Thousands of space heaters sold on Amazon, bat...
# 19  You still have a chance to win some Taylor Swi...
# 20  Ahead of Remembrance Day, Canada Post has issu...
# 21  A new Costco location opened today (Nov. 8) in...
# 22  When considering Canada’s richest citizens, a ...
# 23  If you couldn’t score tickets to Taylor Swift’...
# 24  One goal of the City of Burlington’s review of...
# 25  The Town of Oakville will switch back to purch...
# 26  Drivers in Halton Region should plan ahead due...
# 27  Consultations surrounding design for the new O...
# 28  Two people have been arrested following an att...
# 29  Two arrests have been made following a home in...
# 30  A three-week program to collect loose leaves f...
# 31  A single lane restriction will be in place on ...
# 32  This story is part of a new initiative to prov...
# 33  The Vaughan animal shelter is hosting an anima...
# 34  We’re sharing this information with you, even ...
# 35  The holiday magic of WinterFest returns to Can...
# 36  Vaughan is undergoing several road closures an...
# 37  As the threat of a possible work stoppage at C...
# 38  Thousands of space heaters sold on Amazon, bat...
# 39  You still have a chance to win some Taylor Swi...
# 40  The holiday magic of WinterFest returns to Can...
# 41  The “typical ebb and flow of warmth and cooler...
# 42  As the threat of a possible work stoppage at C...
# 43  Thousands of space heaters sold on Amazon, bat...
# 44  You still have a chance to win some Taylor Swi...

# %% [markdown]
# PERFORMING DATA ANALYSIS ON DATA USING PANDAS

# %% [markdown]
# NEWS BY REGION

# %%
region = "brampton"

# Filter rows where 'body' contains any of the keywords
brampton_news = df[df["url"].str.contains(region, case=False, na=False)]
print(brampton_news)

region = "halton"

# Filter rows where 'body' contains any of the keywords
halton_news = df[df["url"].str.contains(region, case=False, na=False)]
print(halton_news)

# %% [markdown]
# NEWS BY KEYWORD

# %%
keywords = "crime"

# Filter rows where 'body' contains any of the keywords
crime_rows = df[df["description"].str.contains(keywords, case=False, na=False)]
print(crime_rows)
# Out:
#                                                  body  \
# 15  \n        \n\n        Mississauga man charged ...
# 28  \n        \n\n        2 charged with vehicle t...
# 29  \n        \n\n        2 arrested following vio...
#
#                                                   img  \
# 15  https://bloximages.chicago2.vip.townnews.com/m...
# 28  https://bloximages.chicago2.vip.townnews.com/i...
# 29  https://bloximages.chicago2.vip.townnews.com/i...
#
#                                                   url  \
# 15  https://www.mississauga.com/news/crime/mississ...
# 28  https://www.insidehalton.com/news/crime/2-char...
# 29  https://www.insidehalton.com/news/crime/2-arre...
#
#                                           description
# 15  A Mississauga man is one of two people charged...
# 28  Two people have been arrested following an att...
# 29  Two arrests have been made following a home in...

# %% [markdown]
# SAVING IT IN SQLITE DATABASE AND QUERYING THE DATA FOR DISPLAY USING PANDAS READ SQL

# %%
# Connect to SQLite and create a database file
conn = sqlite3.connect('news.db')
 
df.to_sql("Gtanews", conn, if_exists="replace", index=True)

query_statement = f"SELECT * FROM Gtanews"
query_output = pd.read_sql(query_statement, conn)
print(query_statement)
query_output
# Out:
# SELECT * FROM Gtanews
#     index                                               body  \
# 0       0  \n        \n\n        Man rushed to hospital a...
# 1       1  \n        \n\n        Ready for some winter fu...
# 2       2  \n        \n\n        ‘Honour the incredible s...
# 3       3  \n        \n\n        Got mail? Here are other...
# 4       4  \n        \n\n        Ontario, Canada recalls:...
# 5       5  \n        \n\n        ‘LANES CLOSED’: Major la...
# 6       6  \n        \n\n        Still want to see Taylor...
# 7       7  \n        \n\n        New Canada Post stamps p...
# 8       8  \n        \n\n        ‘We’re liable’: Mississa...
# 9       9  \n        \n\n        ‘LANES CLOSED’: Major la...
# 10     10  \n        \n\n        Man with ties to Peel Re...
# 11     11  \n        \n\n        Mississauga Mayor Caroly...
# 12     12  \n        \n\n        MiWay buses not entering...
# 13     13  \n        \n\n        Suspicious package promp...
# 14     14  \n        \n\n        ‘Very difficult’: Missis...
# 15     15  \n        \n\n        Mississauga man charged ...
# 16     16  \n        \n\n        Ready for some winter fu...
# 17     17  \n        \n\n        Got mail? Here are other...
# 18     18  \n        \n\n        Ontario, Canada recalls:...
# 19     19  \n        \n\n        Still want to see Taylor...
# 20     20  \n        \n\n        New Canada Post stamps p...
# 21     21  \n        \n\n        Ontario’s first Costco s...
# 22     22  \n        \n\n        Maclean’s reveals Canada...
# 23     23  \n        \n\n        Rogers Centre selling of...
# 24     24  \n        \n\n        Burlington hosting onlin...
# 25     25  \n        \n\n        Town of Oakville to star...
# 26     26  \n        \n\n        ‘LANES CLOSED’: Signific...
# 27     27  \n        \n\n        Oakville library design ...
# 28     28  \n        \n\n        2 charged with vehicle t...
# 29     29  \n        \n\n        2 arrested following vio...
# 30     30  \n        \n\n        ‘Disrupts critical habit...
# 31     31  \n        \n\n        Burlington Tuck Creek fl...
# 32     32     \n        \n\n        萬錦在加拿大最佳外賣城市中排名第五，僅次於溫哥華
# 33     33  \n        \n\n        Vaughan animal shelter h...
# 34     34  \n        \n\n        Magna International’s Ne...
# 35     35  \n        \n\n        Ready for some winter fu...
# 36     36  \n        \n\n        Here’s a list of road cl...
# 37     37  \n        \n\n        Got mail? Here are other...
# 38     38  \n        \n\n        Ontario, Canada recalls:...
# 39     39  \n        \n\n        Still want to see Taylor...
# 40     40  \n        \n\n        \n            Ready for ...
# 41     41  \n        \n\n        \n            Typical fa...
# 42     42  \n        \n\n        \n            Got mail? ...
# 43     43  \n        \n\n        \n            Ontario, C...
# 44     44  \n        \n\n        \n            Still want...
#
#                                                   img  \
# 0   https://bloximages.chicago2.vip.townnews.com/b...
# 1   https://bloximages.chicago2.vip.townnews.com/b...
# 2   https://bloximages.chicago2.vip.townnews.com/b...
# 3   https://bloximages.chicago2.vip.townnews.com/b...
# 4   https://bloximages.chicago2.vip.townnews.com/b...
# 5   https://bloximages.chicago2.vip.townnews.com/b...
# 6   https://bloximages.chicago2.vip.townnews.com/b...
